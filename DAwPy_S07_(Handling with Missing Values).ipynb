# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>

# %% [markdown]
# <hr>
#
# <a href="https://lms.clarusway.com/mod/lesson/view.php?id=2463&pageid=4531&startlastseen=no"><img align="center" src="https://i.ibb.co/6Z5pQxD/lmss.png" alt="Open in Clarusway LMS" width="70" height="200" title="Open Clarusway Learning Management Sytem"></a>
#
# <a href="https://github.com/clarusway/DS-DE-0322-Students/blob/main/3-%20Classes%26Labs/2-DAwPY/DAwPy_S01_(Numpy_Arrays).ipynb"><img align="left" src="https://i.ibb.co/n3HWyQX/github-logo.png" alt="Open in Clarusway GitHub" width="90" height="150" title="Open and Execute in Clarusway GitHub Repository"></a>
#
# <a href="https://nbviewer.org/github/4dsolutions/clarusway_data_analysis/blob/main/DAwPy_S1_%28Numpy_Arrays%29/DAwPy_S1_%28Numpy_Arrays%29.ipynb"><img align="right" src="https://i.ibb.co/48wtV8c/nbviewer-badge.png" alt="Open in nbviewer" width="100" height="100" title="Open and Execute in nbviewer"></a><br/>
#
# <hr>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="500" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/XS0bxSH/best-bootcamps.png" width="300" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid"
# alt="CLRSWY_Courses"></p>
#
#
# <img src=https://i.ibb.co/6gCsHd6/1200px-Pandas-logo-svg.png width="500" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Session - 07</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:175%; text-align:center; border-radius:10px 10px;">Pandas DataFrames (Handling Missing Values)</p>

# %% [markdown]
# <img src=https://i.ibb.co/RgknJfB/missing-value.png width="700" height="200">
#
#
# **[Working with Missing Data in Pandas](https://pandas.pydata.org/docs/user_guide/missing_data.html)**
#
# Missing Data can occur when no information is provided for one or more items or for a whole unit. Missing Data is a very big problem in a real-life scenarios. Missing Data can also refer to as NA (an acronym for Not Available) values in Pandas. In DataFrame sometimes many datasets simply arrive with missing data, either because it exists and was not collected or it never existed.
#
# **[When and Why Is Data Missed?](https://www.tutorialspoint.com/python_pandas/python_pandas_missing_data.htm)**
#
# Let us consider an online survey where different users being surveyed for a product. Many a times, people do not share all the information related to them. For Example, different users being surveyed may choose not to share their income, some users may choose not to share the address. Few people share their experience, but not how long they are using the product; few people share how long they are using the product, their experience but not their contact information. Thus, in some or the other way a part of data is always missing, and this is very common in real time.
#
#
# **[Missing Value Handling Methods](https://becominghuman.ai/imputing-missing-values-f00a770d9cc4)**
#
# - **``Delete all instances with at least a missing value``**: If you do this method then, the size of the dataset should be large enough to represent the population without those instances.<br>
# - **``Recover redoing the experiment or contacting the subject``**: This is one of the high-cost methods to recover the values, redoing an experiment takes time and cost money, moreover if it's a public opinion kind of dataset, then acts like GDPR restrict future uses to contact the subject in some cases.<br>
# - **``Domain Experts Guessing``**: By consulting the domain experts it is possible to guess the missing values with their experience but this method is a hectic and highly cost method due to the high hourly rates of experts.<br>
# - **``Fill with mean``**: This is one of the easiest and most primary methods of imputing missing values, by filling each missing value with the average of the attribute. This is not always good to use because it reduces the variability of the data but in some cases makes sense.<br>
# - **``Fill with median``**: Similar to the above method the problem is it reduces the variability of the data. Moreover, if the missing values are distributed then it could increase the noise of the data as well.<br>
# - **``Using Machine Learning algorithms``**: There are two different ways of using ML for imputation, first the multiple-regression analysis, by creating a regression equation using the rest of the data it is possible to predict missing values. This method needs more complete instances to train the model. Finally, the most common and popular method is the Multiple Imputation. where there are multiple missing values based on the correlations for the missing data and then averages the simulated datasets by incorporating random errors in your predictions
#
# **🎥 [YouTube Video Source: Python Pandas Tutorial: Handle Missing Data; fillna, dropna, interpolate](https://www.youtube.com/watch?v=EaGbS7eWSs0)**<br>
# **🎥 [YouTube Video Source: Python Pandas Tutorial: Handle Missing Data; replace function](https://www.youtube.com/watch?v=XOxABiMhG2U)**<br>
# **🎥 [YouTube Video Source: Handling Missing Values in Pandas Dataframe](https://www.youtube.com/watch?v=uDr67HBIPz8)**

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#0)
# * [TYPE OF NAN VALUES](#1)
# * [DETECTING MISSING VALUES](#2)
# * [CONVERTING INAPPROPRIATE VALUES TO NAN VALUES](#3)
# * [METHODS FOR HANDLING MISSING VALUES](#4)
# * [THE END OF THE SESSION - 07](#5)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Libraries Needed in This Notebook</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display

# import warnings
# warnings.filterwarnings("ignore")  # to suppress all warnings

# %%
id_no = ["P001", "P002", "P003", "P004", "P005", "P006", "P007", "P008", "P009", "P010", "P011"]  # list of strings
gender = ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"]  # list of strings
status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]  # list of strings with Numpy "nan"
dept = ["DS", "FS", "AWS", "AWS", "DS", None, "FS", "FS", np.nan, "DS", "AWS"]  # list of strings with Numpy "nan" & "None" type
V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6])  # Numpy array with mixed data types (int, str, & np.nan)
V2 = np.array([8, np.nan, 5, 8, 11, np.nan, np.nan, 2, 3, 7, 9])  # Numpy array with mixed data types (int & np.nan)
salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])  # Numpy array with mixed data types (int, None, & np.nan)

df = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %% [markdown]
# **[See the numpy dtype hierarchy](https://numpy.org/doc/stable/reference/arrays.scalars.html)**

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Type of NaN Values</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **🧐 [Values considered “missing”](https://pandas.pydata.org/docs/user_guide/missing_data.html)**
#
# **``NaN``** stands for **``Not A Number``**, and nan values are constants. Its primary constant is to act as a placeholder for any missing numerical values in the array, so is a common missing data representation. It is a special floating-point value and cannot be converted to any other type than float.
#
# As data comes in many shapes and forms, Pandas aims to be flexible with regard to handling missing data. While **``NaN``** is the **default missing value marker** for reasons of **computational speed and convenience**, we need to be able to easily detect this value with data of different types: floating point, integer, boolean, and general object. In many cases, however, the Python **``None``** will arise and we wish to also consider that “missing” or “not available” or “NA”.
#
# **In Pandas missing data is represented by two value:**
#
# - **``None``**: None is a Python singleton object that is often used for missing data in Python code.
# - **``NaN ``**: NaN (an acronym for Not a Number), is a special floating-point value recognized by all systems that use the standard IEEE floating-point representation
#
# **🧐 [Data Cleaning with Python and Pandas: Detecting Missing Values](https://towardsdatascience.com/data-cleaning-with-python-and-pandas-detecting-missing-values-3e9c6ebcf78b)**<br>
# **🧐 [8 Methods For Handling Missing Values With Python Pandas](https://towardsdatascience.com/8-methods-for-handling-missing-values-with-python-pandas-842544cdf891)**<br>
# **🧐 [Missing values in pandas (nan, None, pd.NA)](https://note.nkmk.me/en/python-pandas-nan-none-na/)**<br>
# **🧐 [Handling Missing Data](https://jakevdp.github.io/PythonDataScienceHandbook/03.04-missing-values.html)**<br>
# **🧐 [Practical Strategies to Handle Missing Values](https://towardsdatascience.com/practical-strategies-to-handle-missing-values-626f9c43870b)**

# %% [markdown]
# **Let us first examine the Dataset:**

# %%
df.info()

# Although only one "NaN" value appears in the "status" column, in fact, there are 3 null values.  
# The observations including "-" signs do NOT appear as NaN. 
# Therefore, the dataset needs to be examined in more detail by looking at unique values and value_counts.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    11 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 744.0+ bytes

# %%
class color:
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    RED = '\033[91m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    END = '\033[0m'

def check_obj_columns(df):
    '''
    Returns NO PROBLEM or column/s which has/have mixed object types.
    '''    
    
    tdf = df.select_dtypes(include=['object']).applymap(type)
    for col in tdf:
        if len(set(tdf[col].values)) > 1:
            print("Column" + " " + color.BOLD + color.RED + col + color.END + " " + "has mixed object types." )
    else:
        if len(set(tdf[col].values)) == 1:
            print(color.BOLD + color.GREEN + " " + "NO PROBLEM" + " " + color.END + " " + "with the data types of Columns in the DataFrame.")

check_obj_columns(df)
# Out:
# Column status has mixed object types.
# Column dept has mixed object types.
# Column salary has mixed object types.

# %%
type(np.nan)  # np.nan's default type is float.
# Out:
# float

# %%
type(np.NaN)  # np.NaN's default type is float as well.
# Out:
# float

# %%
type(None)  # None's default type is NoneType.

# Since its type is "NoneType", it may cause you to get an error in some circumstances. 
# It may be necessary to convert them to np.nans.
# Out:
# NoneType

# %% [markdown]
# **``NoneType``** in Python is the data type of the object when the object does not have any value. The None keyword is used to define a null value, or no value at all. None is not the same as 0, False, or an empty string. None is a data type of its own (NoneType) and only None can be None.
#
# **When is NoneType used?**
#
# It is useful in many places. It is the default return type of the function when the function does not return any value.
#
# **Use cases (Examples):**
#
# - If the Python regular expression in re.search does not match, it returns NoneType object.
# - When you search key in the Python dictionary and the key is not present, it returns NoneType object.
# - The None keyword is also used for matching or identifying if a certain function returns any value or not.
#
# **🧐 [What is NoneType in Python and Null Equivalent?](https://www.csestack.org/nonetype-in-python-null/)**

# %% [markdown]
# Let us examine the **Null values** in **``"salary"``**, **``"status"``**, and **``"var1"``** features:

# %%
# Let us remember "salary" feature:

# salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])  # Numpy array with mixed data types (int, None, & np.nan)

df.salary
# Out:
# 0      NaN
# 1       54
# 2       59
# 3      120
# 4       58
# 5       75
# 6     None
# 7      136
# 8       60
# 9      125
# 10     NaN
# Name: salary, dtype: object

# %% [markdown]
# **``NoneType``** in Python is a data type that simply shows that an object has no value/has a value of None. **``None``** and **``NaN``** sound similar, look similar but are actually quite different. None is a Python internal type which can be considered as the equivalent of NULL. The None keyword is used to define a null value, or no value at all. None is not the same as 0, False, or an empty string. It is a datatype of its own (NoneType) and only None can be … None. **While missing values are NaN in numerical arrays, they are None in object arrays.**

# %%
type(df.salary[0])

# The type of the value at the index number 0 of the "salary" column is floating point.
# Out:
# float

# %%
type(df.salary[6])

# The type of the value at the index number 6 of the "salary" column is NoneType.
# Out:
# NoneType

# %%
type(df.salary[1])

# The type of the value at the index number 1 of the "salary" column is integer.
# Out:
# int

# %%
# Let us remember "status" feature:

# status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]  # list of strings with Numpy nan

df.status
# Out:
# 0      FT
# 1      PT
# 2       -
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7       -
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
type(df.status[2])

# The type of the value at the index number 2 of the "status" column is integer.
# Out:
# str

# %%
type(df.status[10])

# Since the values in the "status" column enters the DataFrame in the list format and each element in the list can keep their dtypes, 
# the nan values in this column remain as floats.
# Out:
# float

# %%
# Let's remember "var1" feature:

# V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6])  # Numpy array with mixed data types (int, str, & np.nan)

df.var1
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
type(df.var1[3])  # nan's type became str due to a string ("-") expression in the "var1" column.
# Out:
# str

# %% [markdown]
# **'nan' became a string here, but nan is expected to be a floating-point number.**

# %%
type(df.var1[0])  # Similarly, the types of other values in the "var1" column became string due to a str ("-") expression.
# Out:
# str

# %%
type(df.var1[10])

# type(df.var1.iloc[-1])
# Out:
# str

# %% [markdown]
# **Therfore, it can be concluded that it is so important how any null values came out; are they created by means of list or np.array, etc.?**

# %%
print(0 * np.nan)
print(np.nan is np.nan )
print(np.nan in [np.nan])
print(np.nan == np.nan)
print(np.inf > np.nan)
print(np.nan - np.nan)
print(np.nan + np.nan)
print(np.nan - 10)
print(np.nan + 10)
print(np.nan in set([np.nan]))
print(0.3 == 3 * 0.1)
# Out:
# nan
# True
# True
# False
# False
# nan
# nan
# nan
# nan
# True
# False

# %% [markdown]
# At first, reading that np.nan == np.nan is False can trigger a reaction of confusion and frustration. Although either side of NaN==NaN contains the same value and their type is Number but they are not same. According to ECMA-262, either side of == or === contains NaN then it will result false value. [You may find a details rules in here](https://262.ecma-international.org/5.1/#sec-11.9.3)
#
# **Equality vs Identity**<br>
# To understand why np.nan in [np.nan] is True, we have to look at the difference between equality and identity.
#
# **``Equality``** refers to the concept that most Python programmers know as “==”. This is used to ask Python ``whether the content of the variable is the same as the content of another variable``.The content of NaN is never equal to the content of another NaN.
#
# **``Identity``** is when you are asking Python ``if a variable is the same as another variable``, meaning you are asking Python whether the two variables share the same identity. Python assigns an id to each variable that is created, and ids are compared when Python looks at the identity of a variable in an operation. However, np.nan is a single object that always has the same id, no matter which variable you assign it to.
#
# **Python checks identity before checking equality.**
#
# **🧐 [Why np.nan==np.nan returns False](https://stackoverflow.com/questions/20320022/why-in-numpy-nan-nan-is-false-while-nan-in-nan-is-true)**<br>
# **🧐 [Navigating The Hell of NaNs in Python](https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b)**<br>
# **🧐 [How do you identify NP NaN?](https://fazerpergunta.com/biblioteca/artigo/read/127332-how-do-you-identify-np-nan)**

# %%
a = np.nan
b = np.nan
print(id(a))
print(id(b))

print(a == b)
print(a is b)
# Out:
# 2220468145776
# 2220468145776
# False
# True

# %% [markdown]
# **``nan``** not being equal to nan is part of the definition of nan, so that part's easy.
#
# As for **``nan``** in [nan] being True, that's because identity is tested before equality for containment in lists. You're comparing the same two objects.
#
# The reason for this is that **``== operator``** compares the values of both the operands and checks for value equality. **``is operator``**, on the other hand, checks whether both the operands refer to the same object or not.
#
# In fact, you can print out the **IDs** of both **a** and **b** and see that they **refer to the same object**.
#
# **What is the None keyword in Python? [ANSWER01](https://www.educative.io/edpresso/what-is-the-none-keyword-in-python), [ANSWER02](https://stackoverflow.com/questions/21095654/what-is-a-nonetype-object)**
#
# **Difference between None and NaN in Pandas [ANSWER01](https://www.skytowner.com/explore/difference_between_none_and_nan_in_pandas), [ANSWER02](https://kegui.medium.com/what-is-the-difference-between-nan-none-pd-nan-and-np-nan-a8ee0532e2eb)**
#
# **Difference between np.nan and np.NaN [ANSWER](https://stackoverflow.com/questions/53436339/difference-between-np-nan-and-np-nan)**
#
# **Difference between nan and 'nan' in Python [ANSWER01](https://stackoverflow.com/questions/40309789/difference-between-nan-and-nan-in-python), [ANSWER02](https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b)**

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Detecting Missing Values</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **``NaN``**, standing for **"Not A Number"**, is a numeric data type used to represent any value that is undefined or unpresentable.
#
# For example, 0/0 is undefined as a real number and is, therefore, represented by NaN. The square root of a negative number is an imaginary number that cannot be represented as a real number, so, it is represented by NaN.
#
# **``NaN``** is also assigned to variables, in a computation, that do not have values and have yet to be computed.

# %%
# Let's remember our DataFrame:

df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %% [markdown]
# Pandas **[isnull()](https://pandas.pydata.org/docs/reference/api/pandas.isnull.html)**, and **[isna()](https://pandas.pydata.org/docs/reference/api/pandas.isna.html)** methods are used to check and manage NULL values in a data frame. The function returns a boolean same-sized object indicating if the values are NA. NA values, such as None or numpy.NaN, gets mapped to True values. Everything else gets mapped to False values.
#
# Note: Characters such as empty strings '' or numpy.inf are not considered NA values (unless you set pandas.options.mode.use_inf_as_na = True).

# %%
display(df.isnull())

df.isna()

# Both give the same result. Returns True for null values and False for non-null values.
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# ...

# %% [markdown]
# Pandas **[notnull()](https://pandas.pydata.org/docs/reference/api/pandas.notnull.html)** and **[notna()](https://pandas.pydata.org/docs/reference/api/pandas.notna.html)** functions detects existing/ non-missing values in the dataframe. The function returns a boolean object having the same size as that of the object on which it is applied, indicating whether each individual value is a na value or not. All of the non-missing values gets mapped to true and missing values get mapped to false.
#
# Note : Characters such as empty strings ” or numpy.inf are not considered NA values. (unless you set pandas.options.mode.use_inf_as_na = True).

# %%
display(df.notnull())

df.notna()

# Both give the same result. Returns True for non-null values and False for null values.
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# ...

# %% [markdown]
# **🧐 [Python Documentation on any()](https://docs.python.org/3/library/functions.html)**

# %%
# columns/variables containing any missing values

df.isnull().any()  # Returns True if there is even one null value for the given features of that df at hand.
# Out:
# id        False
# gender    False
# status     True
# dept       True
# var1      False
# var2       True
# salary     True
# dtype: bool

# %%
# rows containing any missing values

df.isnull().any(axis=1)  

# Returns True if there is even one null value for the given rows (observations) of that df at hand.
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %%
# number of missing values in the columns

df.isnull().sum() # isnull().sum() returns the total number of missing values for each feature in the dataset.
# Out:
# id        0
# gender    0
# status    1
# dept      2
# var1      0
# var2      3
# salary    3
# dtype: int64

# %%
# number of missing values in the all DataFrame

df.isnull().sum().sum()  # isnull().sum().sum() returns the total number of missing values in the dataset.
# Out:
# 9

# %%
df.salary.isnull()  # We can see the null values in the "salary" column by elementwise.
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10     True
# Name: salary, dtype: bool

# %%
df.salary.isnull().any()  # We can see if there is any (even one) null value in the "salary" column.
# Out:
# True

# %%
df.salary.isnull().sum() # We can check the total number of missing values in the "salary" feature.
# Out:
# 3

# %%
# Percentage of null values by columns

df.isnull().sum()/len(df)*100  # We calculated the percentage of null values for every variable in dataframe

# df.isnull().sum()/df.shape[0]*100
# Out:
# id         0.000000
# gender     0.000000
# status     9.090909
# dept      18.181818
# var1       0.000000
# var2      27.272727
# salary    27.272727
# dtype: float64

# %%
# to examine rows having missing value

df[df.isnull().any(axis=1)]

# In order to see only the observations with null values in df, 
# we filtered by writing the code that returns boolean values in df with square brackets.
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 8   P009      M     PT   NaN   14   3.0     60
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
# rows containing full of notnull values using "~"

df[~df.isnull().any(axis=1)]

# In order to see only the observations with non-null values in df, 
# we filtered by writing the code that returns boolean values in df with square brackets.
# Out:
#      id gender status dept var1  var2 salary
# 2  P003      M      -  AWS    5   5.0     59
# 3  P004      F     FT  AWS  nan   8.0    120
# 4  P005      M     PT   DS    7  11.0     58
# 7  P008      F      -   FS   10   2.0    136
# 9  P010      F     FT   DS    -   7.0    125

# %% [markdown]
# **📝 Note that there have been "nan" and "-" values whose data type is integer. They do NOOT look like as "NaN" in the DataFrame. 📝**

# %%
# df[df.isnull().all(axis=1)]

df.loc[df.isnull().all(axis=1)]  # We can see if all the values are null in the DataFrame.
# Out:
# Empty DataFrame
# Columns: [id, gender, status, dept, var1, var2, salary]
# Index: []

# %%
# to examine rows having missing value for specific column

# df[df.salary.isnull()]

df.loc[df.salary.isnull()]
# Out:
#       id gender status dept var1  var2 salary
# 0   P001      M     FT   DS    2   8.0    NaN
# 6   P007      M     FT   FS  nan   NaN   None
# 10  P011      M    NaN  AWS    6   9.0    NaN

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Converting Inappropriate Values to NaN Values</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - **[pd.to_numeric()](https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html)**
# - **[Series.map()](https://pandas.pydata.org/docs/reference/api/pandas.Series.map.html0)**
# - **[pd.DataFrame.replace()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html)**

# %%
# Let's remember our DataFrame:

display(df)

df.var1.dtype
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN
# dtype('O')

# %%
for item in df.var1:
    numeric = item.isnumeric()
    print(numeric)
    
# df.var1.str.isnumeric()
# Out:
# True
# True
# True
# False
# True
# True
# False
# True
# True
# False
# True

# %% [markdown]
#  ### a. The first approach to convert inappropriate values

# %%
# The First Approach to Convert Inappropriate Values to NaN Values:

pd.to_numeric(df['var1'], errors='coerce')
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# They key here is the **``errors='coerce'``** parameter of to_numeric
#
# Per **🧐 [the Documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html)** it will replace any value which cannot be converted with **``NaN``**

# %% [markdown]
#  ### b. The second approach to convert inappropriate values

# %%
# The Second Approach Approach to Convert Inappropriate Values to NaN Values:

display(df.var1)
df["var1"].map({"-": np.nan})

# If the dictionary do NOT cover all values in Series, map() method makes all the elements in the Series "NaN". 
# We don't want that.
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# Name: var1, dtype: float64

# %% [markdown]
# **Notes:** When **``arg``** parameter is a dictionary, values in Series that are **NOT** in the dictionary (as keys) are converted to NaN. However, if the dictionary is a dict subclass that defines __missing__ (i.e. provides a method for default values), then this default is used rather than NaN [SOURCE](https://www.w3resource.com/pandas/series/series-map.php#:~:text=The%20map()%20function%20is,a%20dict%20or%20a%20Series.&text=Mapping%20correspondence.&text=If%20'ignore'%2C%20propagate%20NaN,them%20to%20the%20mapping%20correspondence.).

# %% [markdown]
#  ### c. The third approach to convert inappropriate values

# %%
# The Third Approach Approach to Convert Inappropriate Values to NaN Values:

display(df["var1"])
display(df["var1"].replace(to_replace="-", value=np.nan))

# We should write the value we want to change to the "to_replace" parameter and the new value to the "value" parameter. 
# However, the dtype of "var1" feature is still object. This is because it has "nan". To fix this, type change should be made.
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %%
df["var1"].replace("-", np.nan).astype("float")  # To change the data type of all elements in the Series

# df["var1"].replace(["-", "nan"], np.nan)  # Be careful, the dtype of the Series still remaines as object in this way
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
# **[pd.DataFrame.replace()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html)** Returns
#   - DataFrame
#   - Object after replacement.

# %%
df["var1"] = df["var1"].replace("-", np.nan).astype("float")
df["var1"]

# df["var1"] = df["var1"].replace(["-", "nan"], np.nan)
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
# Let's convert the "-" values in the "status" column to "NaN"

df["status"] = df["status"].replace("-", np.nan)
df["status"]

# Nans here remained as string since other data are also string. No data type change needed.
# Out:
# 0      FT
# 1      PT
# 2     NaN
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7     NaN
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
# Let's look at how our DatFrame look like now.

display(df)

df.info()
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  8 non-null      object
#  3   dept    9 non-null      object
#  4   var1    8 non-null      float64
# ...

# %% [markdown]
# Everythings look like great with respect to inappropriate values. Before going further for applying handling methods for miising values, the categorical values in "gender" feature can be converted into numerical ones using map() method; however, it's up to you since you can come over this kind of issue later by applying various methods as well, such as get_dummies(), OneHot Encoding and Label Encoding techniques:

# %%
# Since we specify all the values in the Series inside the dictionary, 
# the map() method makes the desired change without generating any "NaN" values.

df["gender"].map({"M": 1, "F": 0})

# df["gender"].replace({"M" : 1, "F" : 0})  # You can do the same with the replace() method as you did with the map() method above.
# df["gender"].replace(["M", "F"], [1, 0])  # You can also use the replace() method by writing the old values and the new values in the form of a list.
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    1
# Name: gender, dtype: int64

# %%
df.gender
# Out:
# 0     M
# 1     F
# 2     M
# 3     F
# 4     M
# 5     F
# 6     M
# 7     F
# 8     M
# 9     F
# 10    M
# Name: gender, dtype: object

# %%
# After handling inapropriate values in the the DataFrame, let's look at how it looks like now:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
# Let us make cross-check seeing the total number of "NaN" values for each feature

display(df.info())
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  8 non-null      object
#  3   dept    9 non-null      object
#  4   var1    8 non-null      float64
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 744.0+ bytes
# None
# id        0
# gender    0
# status    3
# dept      2
# var1      3
# var2      3
# salary    3
# dtype: int64

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Methods for Handling Missing Values</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
#  1. <b>Deleting (Dropping) Rows</b> ----->if it has more than 70-75% of missing values
#
#  2. <b>Replacing (Filling) With Mean/Median/Mode (Imputation)</b>--->can be applied on a feature which has numeric data
#
#  3. <b> Assigning An Unique Category</b>--->If a categorical feature has definite number of classes, we can assign another class
#
#  4. <b>Predicting The Missing Values</b>---> we can predict the nulls with the help of a machine learning algorithm like linear regression
#
#  5. <b>Using Algorithms Which Support Missing Values</b>--->KNN is a machine learning algorithm which works on the principle of distance measure.  This algorithm can be used when there are nulls present in the dataset.  KNN considers the missing values by taking the majority of the K nearest values

# %% [markdown]
#  ## 1 - Dropping
#
#  - **[pandas.Series.dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dropna.html)**
#  - **[pandas.Series.drop](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.drop.html)**

# %%
# Let's remember our DataFrame:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
# df.dropna() method with how="any" parameter removes the rows which contain any (even one missing value) missing value.

df.dropna(axis=0, how="any", inplace=False)
# df.dropna(axis=0, how="any", thresh=None, inplace=False)  # TypeError: You cannot set both the how and thresh arguments at the same time.

# how : {'any','all'}, default 'any', Determine if row or column is removed from DataFrame, when we have at least one NA or all NA.
# inplace : bool, default False, If True, do operation inplace and return None.
# thresh : Require that many non-NA values.
# Out:
#      id gender status dept  var1  var2 salary
# 4  P005      M     PT   DS   7.0  11.0     58

# %%
# Let's play with "axis" parameter: 

# df.dropna() method with how="any" parameter removes all columns which contain any (even one missing value) missing value.

df.dropna(axis=1, how="any", inplace=False)
# df.dropna(axis=1, how="any", thresh=None, inplace=False)  # TypeError: You cannot set both the how and thresh arguments at the same time.
# Out:
#       id gender
# 0   P001      M
# 1   P002      F
# 2   P003      M
# 3   P004      F
# 4   P005      M
# 5   P006      F
# 6   P007      M
# 7   P008      F
# 8   P009      M
# 9   P010      F
# 10  P011      M

# %%
# df.dropna() method with axis=1 and how="all" parameters removes the column(s) if any column's all values are missing value.

df.dropna(axis=1, how="all", inplace=False)
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# * **[any](https://docs.python.org/3/library/functions.html#any)** : If any NA values are present, drop that row or column.
# * **[all](https://docs.python.org/3/library/functions.html#all)** : If all values are NA, drop that row or column
#
# **🧐 [Pandas dropna() - Drop Null/NA Values from DataFrame](https://www.journaldev.com/33492/pandas-dropna-drop-null-na-values-from-dataframe)**

# %%
# let's create a column containing full of missing value.

df["delete_me"] = np.nan
df
# Out:
#       id gender status  dept  var1  var2 salary  delete_me
# 0   P001      M     FT    DS   2.0   8.0    NaN        NaN
# 1   P002      F     PT    FS   3.0   NaN     54        NaN
# 2   P003      M    NaN   AWS   5.0   5.0     59        NaN
# 3   P004      F     FT   AWS   NaN   8.0    120        NaN
# 4   P005      M     PT    DS   7.0  11.0     58        NaN
# 5   P006      F     PT  None   1.0   NaN     75        NaN
# 6   P007      M     FT    FS   NaN   NaN   None        NaN
# 7   P008      F    NaN    FS  10.0   2.0    136        NaN
# 8   P009      M     PT   NaN  14.0   3.0     60        NaN
# 9   P010      F     FT    DS   NaN   7.0    125        NaN
# 10  P011      M    NaN   AWS   6.0   9.0    NaN        NaN

# %%
# Now let's drop the comlumn containing full of missing values by dropna() method defined by axis=1 and how="all" parameters. 

df.dropna(axis=1, how="all", inplace=True)
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
# Keep only the columns with at least 9 non-NA values.

display(df.info())

df.dropna(axis=1, thresh=9, inplace=False)

# thresh parameter takes integer value which tells minimum amount of non-NAN values to drop.
# When the how and thresh parameters are used together, the thresh parameter has priority over and is superior to the how parameter.
# If this were NOT the case, it should have dropped the "dept" column as well.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  8 non-null      object
#  3   dept    9 non-null      object
#  4   var1    8 non-null      float64
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 744.0+ bytes
# None
#       id gender  dept
# 0   P001      M    DS
# 1   P002      F    FS
# 2   P003      M   AWS
# 3   P004      F   AWS
# 4   P005      M    DS
# 5   P006      F  None
# 6   P007      M    FS
# 7   P008      F    FS
# 8   P009      M   NaN
# 9   P010      F    DS
# 10  P011      M   AWS

# %% [markdown]
# **``thresh=N``** requires that a column has at least N **non-NaNs to survive.** **🧐 [Source](https://stackoverflow.com/questions/51584906/thresh-in-dropna-for-dataframe-in-pandas-in-python/51584935)**

# %%
# By defining index or column labels as well, rows or columns having missing values can be dropped.

df.drop([1, 3, 5])  # To drop the rows with index labels 1, 3, and 5

# df.drop(
#         labels=None,
#         axis: 'Axis' = 0,
#         index=None,
#         columns=None,
#         level: 'Level | None' = None,
#         inplace: 'bool' = False,
#         errors: 'str' = 'raise',
#         )
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 4   P005      M     PT   DS   7.0  11.0     58
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT  NaN  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
# df.drop(["var1", "var2"]) # gives an error

df.drop(["var1", "var2"], axis=1)  # To drop the columns with "var1" and "var2" labels
# Out:
#       id gender status  dept salary
# 0   P001      M     FT    DS    NaN
# 1   P002      F     PT    FS     54
# 2   P003      M    NaN   AWS     59
# 3   P004      F     FT   AWS    120
# 4   P005      M     PT    DS     58
# 5   P006      F     PT  None     75
# 6   P007      M     FT    FS   None
# 7   P008      F    NaN    FS    136
# 8   P009      M     PT   NaN     60
# 9   P010      F     FT    DS    125
# 10  P011      M    NaN   AWS    NaN

# %%
# When we define the "index" parameter, there is no need to specify an axis.

df.drop(index=[1, 3, 5])

# df.drop(
#         labels=None,
#         axis: 'Axis' = 0,
#         index=None,
#         columns=None,
#         level: 'Level | None' = None,
#         inplace: 'bool' = False,
#         errors: 'str' = 'raise',
#         )
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 4   P005      M     PT   DS   7.0  11.0     58
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT  NaN  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
# Likewise, wWhen we define the "columns" parameter, there is no need to specify an axis.

df.drop(columns=["id", "var1"])
# Out:
#    gender status  dept  var2 salary
# 0       M     FT    DS   8.0    NaN
# 1       F     PT    FS   NaN     54
# 2       M    NaN   AWS   5.0     59
# 3       F     FT   AWS   8.0    120
# 4       M     PT    DS  11.0     58
# 5       F     PT  None   NaN     75
# 6       M     FT    FS   NaN   None
# 7       F    NaN    FS   2.0    136
# 8       M     PT   NaN   3.0     60
# 9       F     FT    DS   7.0    125
# 10      M    NaN   AWS   9.0    NaN

# %% [markdown]
#  ## 2 - Filling Missing Values (Imputation)
#
# Before going ahead with imputation, let us remember what is a missing value. a missing value is the part of the dataset that seems missing or is a null value, maybe due to some missing data during research or data collection.
#
# Having a missing value in a machine learning model which will be your next step in your journey after Data Analytics is considered very inefficient and hazardous because of the following reasons:
#
# - Reduces the efficiency of the ML model.
# - Affects the overall distribution of data values.
# - It leads to a biased effect in the estimation of the ML model.
#
# By imputation, we mean to replace the missing or null values with a particular value in the entire dataset. Imputation can be done using any of the following basic techniques. In sum, Imputation methods are those where the missing data are filled in to create a complete data matrix that can be analyzed using standard methods.
#
#  - **[pandas.DataFrame.fillna()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html)**
#  - **[pandas.DataFrame.where()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.where.html)**
#  - **[pandas.DataFrame.interpolate()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.interpolate.html)**

# %%
# Let's remember our first:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
#  ### a. Filling with a specific value

# %%
df.fillna(0)
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0       0
# 1   P002      F     PT   FS   3.0   0.0      54
# 2   P003      M      0  AWS   5.0   5.0      59
# 3   P004      F     FT  AWS   0.0   8.0     120
# 4   P005      M     PT   DS   7.0  11.0      58
# 5   P006      F     PT    0   1.0   0.0      75
# 6   P007      M     FT   FS   0.0   0.0       0
# 7   P008      F      0   FS  10.0   2.0     136
# 8   P009      M     PT    0  14.0   3.0      60
# 9   P010      F     FT   DS   0.0   7.0     125
# 10  P011      M      0  AWS   6.0   9.0       0

# %%
df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"].fillna(0)  # We filled all null values in "var1" column with 0
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      0.0
# 4      7.0
# 5      1.0
# 6      0.0
# 7     10.0
# 8     14.0
# 9      0.0
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
#  ### b. Filling with any Proper Value

# %%
df["var1"].mean()  # We calculated the mean of "var1" column
# Out:
# 6.0

# %%
df["var1"].fillna(df["var1"].mean())  # We filled all null values in "var1" column with the mean of "var1" column
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      6.0
# 4      7.0
# 5      1.0
# 6      6.0
# 7     10.0
# 8     14.0
# 9      6.0
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"].median()  # We calculated the median of "var1" column
# Out:
# 5.5

# %%
df["var1"].fillna(df["var1"].median())  # We filled all null values in "var1" column with the median of "var1" column
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      5.5
# 4      7.0
# 5      1.0
# 6      5.5
# 7     10.0
# 8     14.0
# 9      5.5
# 10     6.0
# Name: var1, dtype: float64

# %%
df.mean(numeric_only=True)  # We calculated the mean of each column in our DataFrame
# Out:
# var1    6.000
# var2    6.625
# dtype: float64

# %%
df.fillna(df.mean(numeric_only=True))  

# We filled all null values in each column of the DataFrame with the mean of each column. However, this is not a preferred method.
# Out:
#       id gender status  dept  var1    var2 salary
# 0   P001      M     FT    DS   2.0   8.000    NaN
# 1   P002      F     PT    FS   3.0   6.625     54
# 2   P003      M    NaN   AWS   5.0   5.000     59
# 3   P004      F     FT   AWS   6.0   8.000    120
# 4   P005      M     PT    DS   7.0  11.000     58
# 5   P006      F     PT  None   1.0   6.625     75
# 6   P007      M     FT    FS   6.0   6.625   None
# 7   P008      F    NaN    FS  10.0   2.000    136
# 8   P009      M     PT   NaN  14.0   3.000     60
# 9   P010      F     FT    DS   6.0   7.000    125
# 10  P011      M    NaN   AWS   6.0   9.000    NaN

# %%
df.fillna({"dept": "other", "var1": df.var1.mean(), "var2": df.var2.median()})

# We can fill each column individually with a different desired value
# Out:
#       id gender status   dept  var1  var2 salary
# 0   P001      M     FT     DS   2.0   8.0    NaN
# 1   P002      F     PT     FS   3.0   7.5     54
# 2   P003      M    NaN    AWS   5.0   5.0     59
# 3   P004      F     FT    AWS   6.0   8.0    120
# 4   P005      M     PT     DS   7.0  11.0     58
# 5   P006      F     PT  other   1.0   7.5     75
# 6   P007      M     FT     FS   6.0   7.5   None
# 7   P008      F    NaN     FS  10.0   2.0    136
# 8   P009      M     PT  other  14.0   3.0     60
# 9   P010      F     FT     DS   6.0   7.0    125
# 10  P011      M    NaN    AWS   6.0   9.0    NaN

# %%
df.mean(numeric_only=True)[["var1", "var2"]]
# Out:
# var1    6.000
# var2    6.625
# dtype: float64

# %%
df.fillna(df.mean(numeric_only=True)[["var1", "var2"]])
# Out:
#       id gender status  dept  var1    var2 salary
# 0   P001      M     FT    DS   2.0   8.000    NaN
# 1   P002      F     PT    FS   3.0   6.625     54
# 2   P003      M    NaN   AWS   5.0   5.000     59
# 3   P004      F     FT   AWS   6.0   8.000    120
# 4   P005      M     PT    DS   7.0  11.000     58
# 5   P006      F     PT  None   1.0   6.625     75
# 6   P007      M     FT    FS   6.0   6.625   None
# 7   P008      F    NaN    FS  10.0   2.000    136
# 8   P009      M     PT   NaN  14.0   3.000     60
# 9   P010      F     FT    DS   6.0   7.000    125
# 10  P011      M    NaN   AWS   6.0   9.000    NaN

# %% [markdown]
# **🔥 where() Replace values where the condition is False. 🔥**
#
# Pandas **``where()``** method is used to check a data frame for one or more condition and return the result accordingly. By default, it replaces the values of the rows where the condition evaluates to **False** with desired value. The **``where()``** method is the opposite of the The **``mask()``** method.

# %%
display(df.isna())
df.notna()
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False    True  False  False  False   False
# 3   False   False   False  False   True  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False   True   True    True
# 7   False   False    True  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False   True  False   False
# 10  False   False    True  False  False  False    True
#       id  gender  status   dept   var1   var2  salary
# 0   True    True    True   True   True   True   False
# 1   True    True    True   True   True  False    True
# 2   True    True   False   True   True   True    True
# 3   True    True    True   True  False   True    True
# ...

# %%
# df.where(pd.notna(df), df.mean(numeric_only=True), axis = "columns")

df.where(cond=df.notna(), other=df.mean(numeric_only=True), axis=1)
# Out:
#       id gender status dept  var1    var2 salary
# 0   P001      M     FT   DS   2.0   8.000    NaN
# 1   P002      F     PT   FS   3.0   6.625     54
# 2   P003      M    NaN  AWS   5.0   5.000     59
# 3   P004      F     FT  AWS   6.0   8.000    120
# 4   P005      M     PT   DS   7.0  11.000     58
# 5   P006      F     PT  NaN   1.0   6.625     75
# 6   P007      M     FT   FS   6.0   6.625    NaN
# 7   P008      F    NaN   FS  10.0   2.000    136
# 8   P009      M     PT  NaN  14.0   3.000     60
# 9   P010      F     FT   DS   6.0   7.000    125
# 10  P011      M    NaN  AWS   6.0   9.000    NaN

# %% [markdown]
# 🔥 **IMPORTANT :** The **``where()``** method assigns False places 🔥

# %%
# Let us remember our DataFrame:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# **Fill NaN values using an interpolation method.**
#
# **[interpolate()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.interpolate.html)** function in Pandas is basically used to fill NA values in the dataframe or series by generating points between given points. Therefore, this is a very powerful function to fill the missing values. It uses various interpolation techniques to fill the missing values rather than hard-coding the value.
#
# **🧐 [How do pandas interpolate missing values?](https://note.nkmk.me/en/python-pandas-interpolate/)**

# %% [raw]
# df.interpolate(
#                 method: 'str' = 'linear',
#                 axis: 'Axis' = 0,
#                 limit: 'int | None' = None,
#                 inplace: 'bool' = False,
#                 limit_direction: 'str | None' = None,
#                 limit_area: 'str | None' = None,
#                 downcast: 'str | None' = None,
#                 **kwargs,
#                ) -> 'DataFrame | None'
# Docstring:
# Fill NaN values using an interpolation method.
#
# Please note that only ``method='linear'`` is supported for DataFrame/Series with a MultiIndex.
#
# Parameters
# ----------
# method : str, default 'linear'
#     Interpolation technique to use. One of:
#
#     * 'linear': Ignore the index and treat the values as equally
#       spaced. This is the only method supported on MultiIndexes.
#     * 'time': Works on daily and higher resolution data to interpolate
#       given length of interval.
#     * 'index', 'values': use the actual numerical values of the index.
#     * 'pad': Fill in NaNs using existing values.
#     * 'nearest', 'zero', 'slinear', 'quadratic', 'cubic', 'spline',
#       'barycentric', 'polynomial': Passed to
#       `scipy.interpolate.interp1d`. These methods use the numerical
#       values of the index.  Both 'polynomial' and 'spline' require that
#       you also specify an `order` (int), e.g.
#       ``df.interpolate(method='polynomial', order=5)``.
#     * 'krogh', 'piecewise_polynomial', 'spline', 'pchip', 'akima',
#       'cubicspline': Wrappers around the SciPy interpolation methods of
#       similar names. See `Notes`.
#     * 'from_derivatives': Refers to
#       `scipy.interpolate.BPoly.from_derivatives` which
#       replaces 'piecewise_polynomial' interpolation method in
#       scipy 0.18.
#
# axis : {{0 or 'index', 1 or 'columns', None}}, default None
#     Axis to interpolate along.
# limit : int, optional
#     Maximum number of consecutive NaNs to fill. Must be greater than 0.
# inplace : bool, default False
#     Update the data in place if possible.
# limit_direction : {{'forward', 'backward', 'both'}}, Optional
#     Consecutive NaNs will be filled in this direction.
#
#     If limit is specified:
#         * If 'method' is 'pad' or 'ffill', 'limit_direction' must be 'forward'.
#         * If 'method' is 'backfill' or 'bfill', 'limit_direction' must be
#           'backwards'.
#
#     If 'limit' is not specified:
#         * If 'method' is 'backfill' or 'bfill', the default is 'backward'
#         * else the default is 'forward'
#
#     .. versionchanged:: 1.1.0
#         raises ValueError if `limit_direction` is 'forward' or 'both' and method is 'backfill' or 'bfill'.
#         raises ValueError if `limit_direction` is 'backward' or 'both' and method is 'pad' or 'ffill'.
#
# limit_area : {{`None`, 'inside', 'outside'}}, default None
#     If limit is specified, consecutive NaNs will be filled with this restriction.
#
#     * ``None``: No fill restriction.
#     * 'inside': Only fill NaNs surrounded by valid values (interpolate).
#     * 'outside': Only fill NaNs outside valid values (extrapolate).
#
# downcast : optional, 'infer' or None, defaults to None
#     Downcast dtypes if possible.
# ``**kwargs`` : optional
#     Keyword arguments to pass on to the interpolating function.
#
# Returns
# -------
# Series or DataFrame or None
#     Returns the same object type as the caller, interpolated at some or all ``NaN`` values or None if ``inplace=True``.
#
# See Also
# --------
# fillna : Fill missing values using different methods.
# scipy.interpolate.Akima1DInterpolator : Piecewise cubic polynomials (Akima interpolator).
# scipy.interpolate.BPoly.from_derivatives : Piecewise polynomial in the Bernstein basis.
# scipy.interpolate.interp1d : Interpolate a 1-D function.
# scipy.interpolate.KroghInterpolator : Interpolate polynomial (Krogh interpolator).
# scipy.interpolate.PchipInterpolator : PCHIP 1-d monotonic cubic interpolation.
# scipy.interpolate.CubicSpline : Cubic spline data interpolator.
#
# Notes
# -----
# The 'krogh', 'piecewise_polynomial', 'spline', 'pchip' and 'akima' methods are wrappers around the respective SciPy implementations of similar names. These use the actual numerical values of the index.
# For more information on their behavior, see the
# `SciPy documentation
# <https://docs.scipy.org/doc/scipy/reference/interpolate.html#univariate-interpolation>`__and `SciPy tutorial
# <https://docs.scipy.org/doc/scipy/reference/tutorial/interpolate.html>`__.
#
# Examples
# --------
# Filling in ``NaN`` in a :class:`~pandas.Series` via linear interpolation.

# %%
df.interpolate()
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   6.5     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   6.0   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   8.0     75
# 6   P007      M     FT    FS   5.5   5.0   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS  10.0   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# For more information about **🧐 [interpolation](https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/)**

# %% [markdown]
#  ### c.Filling the Missing Values of Categorical Variables

# %%
# Let's remember our DataFrame:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
# Null values of data containing categorical values can be filled using the mode, ffill, bfill properties.

df["dept"].mode()  

# We found the mode for "dept" column. However, be careful we have 3 values for mode.
# There may be a problem with which mode value needed to fill the missing values. To solve this, we need to index.
# Out:
# 0    AWS
# 1     DS
# 2     FS
# Name: dept, dtype: object

# %%
# We can select the first mode value of the dept column by indexing and fill the null values with the mode value we selected.

df["dept"].mode()[0]

# np.random.choice(df.dept.mode())
# Out:
# 'AWS'

# %%
display(df["dept"].fillna(df["dept"].mode()[0]))

display(df["dept"].fillna(np.random.choice(df.dept.mode())))
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5     AWS
# 6      FS
# 7      FS
# 8     AWS
# 9      DS
# 10    AWS
# Name: dept, dtype: object
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5     AWS
# 6      FS
# 7      FS
# 8     AWS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
df["dept"].fillna(method="bfill")

# The bfill method is used to fill the null values in the dept column with the next value.
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5      FS
# 6      FS
# 7      FS
# 8      DS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
df["status"].fillna(method="ffill")

# The ffill method is used to fill the null values in the dept column with the previous value.
# Out:
# 0     FT
# 1     PT
# 2     PT
# 3     FT
# 4     PT
# 5     PT
# 6     FT
# 7     FT
# 8     PT
# 9     FT
# 10    FT
# Name: status, dtype: object

# %% [markdown]
# - **pad / ffill:** propagate last valid observation forward to next valid
# - **backfill / bfill:** use next valid observation to fill gap.

# %% [markdown]
#  ### d. Filling by condition & by Group of the Categorical Variables

# %%
# Let us remember pur DataFrame:

df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df["dept"].fillna(method="ffill", inplace=True)
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# **Let's fill the missing values at "status" column with defined condition by "salary"**

# %%
df[["status", "salary"]]
# Out:
#    status salary
# 0      FT    NaN
# 1      PT     54
# 2     NaN     59
# 3      FT    120
# 4      PT     58
# 5      PT     75
# 6      FT   None
# 7     NaN    136
# 8      PT     60
# 9      FT    125
# 10    NaN    NaN

# %%
df.loc[df["salary"] >= 100, "status"]

# It is seen that the status of those whose salary is equal to and more than 100 is mostly FT. 
# Therefore, it would be logical to fill the values that are null in the status column and whose salary is equal to and more than 100 with FT.
# Out:
# 3     FT
# 7    NaN
# 9     FT
# Name: status, dtype: object

# %%
df.loc[df["salary"] < 100, "status"]

# It is seen that the status of those whose salary is less than 100 is mostly PT. 
# Therefore, it would be logical to fill the values that are null in the status column and whose salary is less than 100 with PT.
# Out:
# 1     PT
# 2    NaN
# 4     PT
# 5     PT
# 8     PT
# Name: status, dtype: object

# %%
# inplace=True didn't work

df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"] >= 100, "status"].mode()[0], inplace=True)
df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"] < 100, "status"].mode()[0], inplace=True)
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# 🔥 **IMPORTANT :** Even if **``fillna()``** method has a inplace parameter, when inplace parameter are used with loc[ ] it does **NOT work** 🔥

# %%
df.loc[df["salary"] >= 100, "status"] = df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0])
df.loc[df["salary"] < 100, "status"] = df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0])
df

# Since inplace parameter doesn't work with loc, we can instead make changes permanent with assignment.
# However, the assignment has to match with the condition created by loc[ ]; otherwise, you will make changes at whole DataFrame.
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# **Let's fill the last missing value at "status" column with the mode of the group of "gender" and "dept"**

# %%
# First Approach: If you have get "ValueError 1 is not in range The above exception was the direct cause of the following exception"
# while indexing, run the code below 

df[["gender", "dept", "status", "salary"]]
# Out:
#    gender dept status salary
# 0       M   DS     FT    NaN
# 1       F   FS     PT     54
# 2       M  AWS     PT     59
# 3       F  AWS     FT    120
# 4       M   DS     PT     58
# 5       F   DS     PT     75
# 6       M   FS     FT   None
# 7       F   FS     FT    136
# 8       M   FS     PT     60
# 9       F   DS     FT    125
# 10      M  AWS    NaN    NaN

# %% [markdown]
# We couldn't fill missing value at the last row in the "status" column above because its corresponding value at the last row of the "salary column has a NaN value as well. To fill this missing value at the "status" column, let's first examine the modes by grouping them by gender and department. Then we can decide which of the mod values we find to fill in the missing values.

# %%
df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode())
# Out:
# gender  dept
# F       AWS   0    FT
#         DS    0    FT
#               1    PT
#         FS    0    FT
#               1    PT
# M       AWS   0    PT
#         DS    0    FT
#               1    PT
#         FS    0    FT
#               1    PT
# Name: status, dtype: object

# %%
# df.groupby(["gender", "dept"])["status"].agg(lambda x: pd.Series.mode(x))

df.groupby(["gender", "dept"])["status"].agg(lambda x: pd.Series.mode(x)[0])
# Out:
# gender  dept
# F       AWS     FT
#         DS      FT
#         FS      FT
# M       AWS     PT
#         DS      FT
#         FS      FT
# Name: status, dtype: object

# %%
df.groupby(["gender", "dept"], as_index=True)["status"].apply(lambda x: pd.Series.mode(x)[0])

# df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode()[0]).reset_index(drop=True)
# Out:
# gender  dept
# F       AWS     FT
#         DS      FT
#         FS      FT
# M       AWS     PT
#         DS      FT
#         FS      FT
# Name: status, dtype: object

# %%
df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0])
# Out:
# 0     FT
# 1     FT
# 2     PT
# 3     FT
# 4     FT
# 5     FT
# 6     FT
# 7     FT
# 8     FT
# 9     FT
# 10    PT
# Name: status, dtype: object

# %% [markdown]
# Since the transform() method returns the same length as input it is more logical to use the transform() method for feature engineering rather than using the apply() method. Otherwise, you will get NaN values in the new feature you created with apply() method. So the transform() method will be used to fill missing values in the DataFame.

# %%
df.groupby(["gender", "dept"])["status"].apply(lambda x: x.mode()).index
# Out:
# MultiIndex([('F', 'AWS', 0),
#             ('F',  'DS', 0),
#             ('F',  'DS', 1),
#             ('F',  'FS', 0),
#             ('F',  'FS', 1),
#             ('M', 'AWS', 0),
#             ('M',  'DS', 0),
#             ('M',  'DS', 1),
#             ('M',  'FS', 0),
#             ('M',  'FS', 1)],
#            names=['gender', 'dept', None])

# %% [markdown]
# **``Special Note:``** The index of df was RangeIndex(start=0, stop=2, step=1). Therefore, RangeIndex vs MultiIndex mismatach caused the issue.
#
# df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode()).index
#
# **How to solve MultiIndex issue while using groupby() and apply()?**

# %% [markdown]
# You can groupy the 'gender' and 'dept' columns and then call apply on the df groupby object and pass the function mode. We can then call reset_index and pass param drop=True so that the multi-index is not added back as a column as you already have those columns:
#
# [How to group by mode in python?](https://stackoverflow.com/questions/30216921/how-to-group-by-mode-in-python)

# %%
# Second Approach: If you have get "ValueError 1 is not in range The above exception was the direct cause of the following exception"
# # while indexing, apply reset_index(drop=True) for the problem  

# df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode()).reset_index(drop=True)
df.groupby(["gender", "dept"])["status"].apply(lambda x : x.mode()[0]).reset_index(drop=True)
# Out:
# 0    FT
# 1    FT
# 2    FT
# 3    PT
# 4    FT
# 5    FT
# Name: status, dtype: object

# %%
df.groupby(["gender", "dept"])["status"].transform(lambda x: pd.Series.mode(x)[0])
# Out:
# 0     FT
# 1     FT
# 2     PT
# 3     FT
# 4     FT
# 5     FT
# 6     FT
# 7     FT
# 8     FT
# 9     FT
# 10    PT
# Name: status, dtype: object

# %%
df["trans_status"] = df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0]).reset_index(drop=True)
df
# Out:
#       id gender status dept  var1  var2 salary trans_status
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT
# 1   P002      F     PT   FS   3.0   NaN     54           FT
# 2   P003      M     PT  AWS   5.0   5.0     59           PT
# 3   P004      F     FT  AWS   NaN   8.0    120           FT
# 4   P005      M     PT   DS   7.0  11.0     58           FT
# 5   P006      F     PT   DS   1.0   NaN     75           FT
# 6   P007      M     FT   FS   NaN   NaN   None           FT
# 7   P008      F     FT   FS  10.0   2.0    136           FT
# 8   P009      M     PT   FS  14.0   3.0     60           FT
# 9   P010      F     FT   DS   NaN   7.0    125           FT
# 10  P011      M    NaN  AWS   6.0   9.0    NaN           PT

# %%
df["status"].fillna(df.groupby(["gender", "dept"])["status"].transform(lambda x : x.mode()[0]).reset_index(drop=True), inplace=True)

# df["status"].fillna(df["trans_status"], inplace=True)
df

# We used the values we obtained with the transform method to fill the null values.
# Out:
#       id gender status dept  var1  var2 salary trans_status
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT
# 1   P002      F     PT   FS   3.0   NaN     54           FT
# 2   P003      M     PT  AWS   5.0   5.0     59           PT
# 3   P004      F     FT  AWS   NaN   8.0    120           FT
# 4   P005      M     PT   DS   7.0  11.0     58           FT
# 5   P006      F     PT   DS   1.0   NaN     75           FT
# 6   P007      M     FT   FS   NaN   NaN   None           FT
# 7   P008      F     FT   FS  10.0   2.0    136           FT
# 8   P009      M     PT   FS  14.0   3.0     60           FT
# 9   P010      F     FT   DS   NaN   7.0    125           FT
# 10  P011      M     PT  AWS   6.0   9.0    NaN           PT

# %% [markdown]
# **Let's fill the missing values at "salary" column with the mean of the group of "status" and "dept"**

# %%
# Let us examine the average of "salary" in terms of "department"

df.groupby("dept")["salary"].mean()
# Out:
# dept
# AWS         89.5
# DS          86.0
# FS     83.333333
# Name: salary, dtype: object

# %%
# Let us examine the average of "salary" in terms of "department" and "status"

df.groupby(["status", "dept"])["salary"].mean()
# Out:
# status  dept
# FT      AWS     120.0
#         DS      125.0
#         FS      136.0
# PT      AWS      59.0
#         DS       66.5
#         FS       57.0
# Name: salary, dtype: object

# %%
# Let's use the transform() method again to find the average salary of the groups according to status and dept in consistent with df length.

df.groupby(["status", "dept"])["salary"].transform("mean")
# Out:
# 0     125.0
# 1      57.0
# 2      59.0
# 3     120.0
# 4      66.5
# 5      66.5
# 6     136.0
# 7     136.0
# 8      57.0
# 9     125.0
# 10     59.0
# Name: salary, dtype: object

# %%
df["trans_salary"] = df.groupby(["status","dept"])["salary"].transform("mean")
df

# For a better understanding of which value will be used for filling, we created a new feature using transform() method 
# demonstrating the average salary of the groups according to status and department.
# Out:
#       id gender status dept  var1  var2 salary trans_status trans_salary
# 0   P001      M     FT   DS   2.0   8.0    NaN           FT        125.0
# 1   P002      F     PT   FS   3.0   NaN     54           FT         57.0
# 2   P003      M     PT  AWS   5.0   5.0     59           PT         59.0
# 3   P004      F     FT  AWS   NaN   8.0    120           FT        120.0
# 4   P005      M     PT   DS   7.0  11.0     58           FT         66.5
# 5   P006      F     PT   DS   1.0   NaN     75           FT         66.5
# 6   P007      M     FT   FS   NaN   NaN   None           FT        136.0
# 7   P008      F     FT   FS  10.0   2.0    136           FT        136.0
# 8   P009      M     PT   FS  14.0   3.0     60           FT         57.0
# 9   P010      F     FT   DS   NaN   7.0    125           FT        125.0
# 10  P011      M     PT  AWS   6.0   9.0    NaN           PT         59.0

# %%
# Now it's time to fill missing values in the "salary" column by the average salary of the groups according to status and department

df["salary"].fillna(df.groupby(["status", "dept"])["salary"].transform("mean"), inplace=True)
# df["salary"].fillna(df["trans_salary"], inplace=True)

df
# Out:
#       id gender status dept  var1  var2  salary trans_status trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT        125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT         57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT         59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0           FT        120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT         66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT         66.5
# 6   P007      M     FT   FS   NaN   NaN   136.0           FT        136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT        136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT         57.0
# 9   P010      F     FT   DS   NaN   7.0   125.0           FT        125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT         59.0

# %% [markdown]
# **Let's fill the missing values at "var1" column with the mean of the group of "gender" and "status"**

# %%
# Let us first check the average value for "var1" according to "gender"

df.groupby("gender").var1.mean()
# Out:
# gender
# F    4.666667
# M    6.800000
# Name: var1, dtype: float64

# %%
# Then let's examine the average value for "var1" according to "gender" and "status"
# Using these values seems more appropriate for the ordinary course of life.

df.groupby(["gender", "status"])["var1"].mean()
# Out:
# gender  status
# F       FT        10.0
#         PT         2.0
# M       FT         2.0
#         PT         8.0
# Name: var1, dtype: float64

# %%
df.groupby(["gender","status"])["var1"].transform("mean")
# Out:
# 0      2.0
# 1      2.0
# 2      8.0
# 3     10.0
# 4      8.0
# 5      2.0
# 6      2.0
# 7     10.0
# 8      8.0
# 9     10.0
# 10     8.0
# Name: var1, dtype: float64

# %%
trans_var1 = df.groupby(["gender", "status"])["var1"].transform("mean")
trans_var1

# We created an object to use while filling missing values in the "var1" column with the average value according to gender and status.
# Out:
# 0      2.0
# 1      2.0
# 2      8.0
# 3     10.0
# 4      8.0
# 5      2.0
# 6      2.0
# 7     10.0
# 8      8.0
# 9     10.0
# 10     8.0
# Name: var1, dtype: float64

# %%
df["var1"].fillna(trans_var1, inplace=True)
df

# We filled the missing values permanently in the "var1" column with the average value according to gender and status.
# Out:
#       id gender status dept  var1  var2  salary trans_status trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0           FT        125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0           FT         57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0           PT         59.0
# 3   P004      F     FT  AWS  10.0   8.0   120.0           FT        120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0           FT         66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0           FT         66.5
# 6   P007      M     FT   FS   2.0   NaN   136.0           FT        136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0           FT        136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0           FT         57.0
# 9   P010      F     FT   DS  10.0   7.0   125.0           FT        125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0           PT         59.0

# %% [markdown]
# **Let's fill the missing values at "var2" column with the mean of group of "status"**

# %%
# Let's remember first "var2" feature

df["var2"]
# Out:
# 0      8.0
# 1      NaN
# 2      5.0
# 3      8.0
# 4     11.0
# 5      NaN
# 6      NaN
# 7      2.0
# 8      3.0
# 9      7.0
# 10     9.0
# Name: var2, dtype: float64

# %%
# Let us check the average value for "var2" according to "status"

df.groupby(["status"])["var2"].mean()
# Out:
# status
# FT    6.25
# PT    7.00
# Name: var2, dtype: float64

# %%
trans_var2 = df.groupby(["status"])["var2"].transform("mean")
trans_var2

# We created an object to use while filling missing values in the "var2" column with the average value according to status.
# Out:
# 0     6.25
# 1     7.00
# 2     7.00
# 3     6.25
# 4     7.00
# 5     7.00
# 6     6.25
# 7     6.25
# 8     7.00
# 9     6.25
# 10    7.00
# Name: var2, dtype: float64

# %%
df["var2"].fillna(trans_var2, inplace=True)

# We filled the missing values permanently in the "var2" column with the average value according to status.

# %%
# Let's look at the last apperance of our DataFrame.

df
# Out:
#       id gender status dept  var1   var2  salary trans_status trans_salary
# 0   P001      M     FT   DS   2.0   8.00   125.0           FT        125.0
# 1   P002      F     PT   FS   3.0   7.00    54.0           FT         57.0
# 2   P003      M     PT  AWS   5.0   5.00    59.0           PT         59.0
# 3   P004      F     FT  AWS  10.0   8.00   120.0           FT        120.0
# 4   P005      M     PT   DS   7.0  11.00    58.0           FT         66.5
# 5   P006      F     PT   DS   1.0   7.00    75.0           FT         66.5
# 6   P007      M     FT   FS   2.0   6.25   136.0           FT        136.0
# 7   P008      F     FT   FS  10.0   2.00   136.0           FT        136.0
# 8   P009      M     PT   FS  14.0   3.00    60.0           FT         57.0
# 9   P010      F     FT   DS  10.0   7.00   125.0           FT        125.0
# 10  P011      M     PT  AWS   6.0   9.00    59.0           PT         59.0

# %% [markdown]
# ### e. Filling with Interpolation
#
# Pandas **``dataframe.interpolate()``** function is basically used to fill NA values in the dataframe or series. But, this is a very powerful function to fill the missing values. It uses various interpolation technique to fill the missing values rather than hard-coding the value [Source 01](https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/), [Source 02](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html) & [Source 03](https://note.nkmk.me/en/python-pandas-interpolate/)

# %%
df = pd.DataFrame({'col1': [0, np.nan, 7, 3, 4],
                   'col2': [np.nan, 1, 2, np.nan, np.nan],
                   'col3': [4, np.nan, np.nan, 7, 10]})
df
#    col1  col2  col3
# 0   0.0   NaN   4.0
# 1   NaN   1.0   NaN
# 2   NaN   2.0   NaN
# 3   3.0   NaN   7.0
# 4   4.0   NaN  10.0
# Out:
#    col1  col2  col3
# 0   0.0   NaN   4.0
# 1   NaN   1.0   NaN
# 2   7.0   2.0   NaN
# 3   3.0   NaN   7.0
# 4   4.0   NaN  10.0

# %%
df.interpolate()
# Out:
#    col1  col2  col3
# 0   0.0   NaN   4.0
# 1   3.5   1.0   5.0
# 2   7.0   2.0   6.0
# 3   3.0   2.0   7.0
# 4   4.0   2.0  10.0

# %% [markdown]
# By default, linear interpolation is done for each column. The same value is repeated for Nan at the bottom, and Nan at the top is unchanged.

# %%
flights = sns.load_dataset("flights")

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.isnull().sum()
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
# You don't need to know how this plotting happens.
# Just focus on the time-series line

flights.passengers.plot();

# %%
flights_copy = flights.copy()

# %%
flights_copy.loc[np.random.randint(1, 144, 20), "passengers"] = None

# %%
flights_copy.isnull().sum()
# Out:
# year           0
# month          0
# passengers    20
# dtype: int64

# %%
flights_copy.passengers.plot();

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

flights_copy["passengers"].interpolate().plot(kind="line");

# %%
plt.figure(figsize = (10, 6))

flights.passengers.plot();

# %%
plt.figure(figsize = (10, 6))

flights_copy["passengers"].fillna(method = "ffill").plot(kind="line");

# %% [markdown]
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">End of the Session - 07</p>
#
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid"
# alt="CLRSWY"></p>
#
#
# <br><br><br>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/Rpz9L36/clarusway-logo-black.png" width="450" height="200" class="img-fluid" alt="CLRSWY_LOGO"></p>
#
# <p style="background-color:#E51A59; font-family:newtimeroman; color:#FDFEFE; font-size:130%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <a href="https://clarusway.com/contact-us/"><img align="center" src="https://i.ibb.co/B43qn24/officially-licensed-logo.png" alt="Open in Clarusway LMS" width="110" height="200" title="This notebook is licensed by Clarusway IT training school. Please contact the authorized persons about the conditions under which you can use or share."></a>
